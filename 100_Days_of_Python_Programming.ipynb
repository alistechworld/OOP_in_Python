# %% [markdown]
# <a href="https://colab.research.google.com/github/alistechworld/OOP_in_Python/blob/main/100_Days_of_Python_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is Python?**

# %% [markdown]
# **Python** is a high-level, easy-to-learn programming language used to build all kinds of applications — websites, software, automation tools, data analysis, machine learning, and much more.

# %% [markdown]
# **Why Python is Popular:**

# %% [markdown]
# **Simple syntax** – looks like English, easy to read and write.
#
# **Free and Open Source** – available for everyone.
#
# **Huge library support** – especially for AI, data science, and automation.
#
# **Community support** – millions of developers are using and improving Python.

# %% [markdown]
# **Real-World Examples of Python in AI**

# %% [markdown]
# **Google Assistant / Siri** – built using NLP and deep learning.
#
# **Netflix Recommendation System** – uses machine learning to suggest shows.
#
# **Self-driving cars** – use Python in vision and decision-making systems.
#
# **Medical diagnosis** – AI models in Python help doctors detect diseases early.

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(4.6)
# Out:
# 4.6

# %%
print(False)
# Out:
# False

# %%
print("Ali", "Nawaz", "Khalid")
# Out:
# Ali Nawaz Khalid

# %%
print("Ali", 6, 5.6)
# Out:
# Ali 6 5.6

# %%
# Python Data types Categories

# %%
# Basic Types:
  # Int Whole number(1, 2, 3)
  # Float Decimals(3.14, 2.5...)
  # Complex Rel + Imag (1 + 2j)
  # Bool Tru/False
  # Str Text("Hello")

# %%
# Container Types:
  # List Order items [1,2,3,4]
  # Tuple Order, immutable
  # Set Unordered, Unique
  # Dict Key-Value Pair

# %%
# User Defined Type:
  # Class

# %%
# int
print(1)
print(2, 3)
# Out:
# 1
# 2 3

# %%
# Float
print(1.4)
# Out:
# 1.4

# %%
# Bool
print(True)
print(False)
# Out:
# True
# False

# %%
# Complex
print(4 + 5j)
# Out:
# (4+5j)

# %%
# Str
print("Lahore")
# Out:
# Lahore

# %%
# List
print([1, 2, 3, 4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1, 2, 3, 4, 5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Dict
print({"Name": "Ali"})
# Out:
# {'Name': 'Ali'}

# %%
# Additiong Progaram
a = 12
b = 10
print(a + b)
# Out:
# 22

# %%
# Variables

# %%
# int a = 5;

# %%
name = "Ali Nawaz"
print(name)
# Out:
# Ali Nawaz

# %%
# Dynamic typing
# Static Typing

# %%
name = "Hello World"
print(name)
# Out:
# Hello World

# %%
age = 25
print(age)
# Out:
# 25

# %%
type(age)
# Out:
# int

# %%
height = 5.6
print(height)
# Out:
# 5.6

# %%
type(height)
# Out:
# float

# %%
# Special Syntax
a = 5; b = 7; c = 9
print(a)
print(b)
print(c)
# Out:
# 5
# 7
# 9

# %%
a, b, c = 5, 7, 9
print(a)
print(b)
print(c)
# Out:
# 5
# 7
# 9

# %%
# Keywords and Identifiers

# %%
# Keywords:
  # Reserved Words , Special meaning
  #

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Identifiers:
  #

# %%
# Rules
  # Strat with letter or _
  # Fllowd by letters, digits, -
  # Not a python keywords

# %%
name = "Ali Nawaz"
print(name)
# Out:
# Ali Nawaz

# %%
_ = "Ali"
print(_)
# Out:
# Ali

# %%
first_name = "Nawaz"
print(first_name)
# Out:
# Nawaz

# %%
True = "Ali"
print(True)
# Out:
#   File "/tmp/ipython-input-9-3825149948.py", line 1
#     True = "Ali"
#     ^
# SyntaxError: cannot assign to True

# %%
# User Input

# %%
input()
# Out:
# This is input
# 'This is input'

# %%
age = input("Enter your age:")
# Out:
# Enter your age:35

# %%
print(age)
# Out:
# 35

# %%
first_num = input("Enter your first num:")
second_num = input("Enter your second num:")
print(first_num)
print(second_num)
# Out:
# Enter your first num:10
# Enter your second num:20
# 10
# 20

# %%
result = first_num + second_num
print(result)
# Out:
# 1020

# %%
type(first_num)
# Out:
# str

# %%
type(second_num)
# Out:
# str

# %%
# Type Conversion

# %%
# Implicit
# Explicit

# %%
print(1 + 2.5)
# Out:
# 3.5

# %%
# Implicit
int('4')
# Out:
# 4

# %%
type(4)
# Out:
# int

# %%
# int to str
str(5)
# Out:
# '5'

# %%
# Float
float(4)
# Out:
# 4.0

# %%
int(45)
# Out:
# 45

# %%
float(4)
# Out:
# 4.0

# %%
str(5)
# Out:
# '5'

# %%
bool(1)
# Out:
# True

# %%
complex(4)
# Out:
# (4+0j)

# %%
list("Hello")
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
first_num = int(input("Enter your first num:"))
second_num = int(input("Enter your second num:"))
print(first_num)
print(second_num)
# Out:
# Enter your first num:10
# Enter your second num:20
# 10
# 20

# %%
result = (first_num) + (second_num)
print(result)
# Out:
# 30

# %%
# Literals in Python

# %%
# Numerial Literals
a = 100

# Float
f2 = 1.5e2

# Complex
x = 3.14j

print(a, f2, x)
# Out:
# 100 150.0 3.14j

# %%
# String Literals
string = 'This is Python'
strings = "This is Python"
multi_string = """This is multi line string"""

print(string)
print(strings)
print(multi_string)
# Out:
# This is Python
# This is Python
# This is multi line string

# %%
# Boolen Literals
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
# Special Literal
k = None

# %%
k

# %%
# Lambda Functions
# Anonymous Functions
# Single Expression Limit.
# Syntax: lambda args: expr
# Example: lambda a, b, : a + b

# %%
x  = lambda x: x**2
x(9)
# Out:
# 81

# %%
a = lambda x, y : x + y
a(4, 5)
# Out:
# 9

# %%
b = lambda x: x[0] == 'a'
b('apple')
# Out:
# True

# %%
b('banana')
# Out:
# False

# %%
b = lambda x : 'Even' if x%2 == 0 else 'Odd'
b(3)
# Out:
# 'Odd'

# %%
b(2)
# Out:
# 'Even'

# %%
L = [11, 14, 27, 21, 23, 56, 78, 39, 45, 29, 28, 30]
def return_sum(func, L):
    result = 0
    for i in L:
        if func(i):
            result = result + i
    return result
x = lambda x : x%2 == 0 # Even Sum
y = lambda x : x%2 != 0 # Odd Sum
z = lambda x : x%3 == 0 # Div3 Sum
print(return_sum(x, L))
print(return_sum(y, L))
print(return_sum(z, L))
# Out:
# 206
# 195
# 240

# %%
# Map
# Applies a function to each item in iterable.

# Syntax:
# map(function, iterable)

# %%
L = [1, 2, 3, 4, 5, 6, 7]

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
map(lambda x: x * 2, L)

# %%
list(map(lambda x: x * 2, L))
# Out:
# [2, 4, 6, 8, 10, 12, 14]

# %%
list(map(lambda x: x % 2 == 0, L))
# Out:
# [False, True, False, True, False, True, False]

# %%
students = [
    {
        "name" : "Jacob Martin",
        "Father name" : "Ros Martin",
        "Address" : "123 Hills Street",
    },{
        "name" : "Angela Stevens",
        "Father name" : "Robert Stevens",
        "Address" : "3 Upper Street London",
    },{
        "name" : "Ricky Smart",
        "Father name" : "William Smart",
        "Address" : "Unknown",
    }

]

list(map(lambda student : student['Father name'], students))
# Out:
# ['Ros Martin', 'Robert Stevens', 'William Smart']

# %%
# Filter
# Applies a function to a sequence
# syntax:
# filter(function, sequence)

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
list(filter(lambda x : x > 4, L))
# Out:
# [5, 6, 7]

# %%
fruits = ['Apple', 'Orange', 'Mango', 'Guava']

# %%
list(filter(lambda fruit : 'e' in fruit, fruits))
# Out:
# ['Apple', 'Orange']

# %%
# Reduce
# Reduces an iterable to a single value.

# %%
import functools

# %%
L
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
functools.reduce(lambda x, y : x + y, L)
# Out:
# 28

# %%
L1 = [12, 34, 56, 11, 21, 58]

# %%
functools.reduce(lambda x, y : x if x > y else y, L1)
# Out:
# 58

# %%
functools.reduce(lambda x, y : x if x < y else y, L1)
# Out:
# 11
